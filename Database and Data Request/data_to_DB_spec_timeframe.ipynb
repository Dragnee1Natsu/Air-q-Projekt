# %%
#Funtkion für Jede Zeitraum

# %%
# Module Imports

#DB stuff
import mariadb
import sys

#Encryption Stuff
import base64
from Crypto.Cipher import AES
import http.client
from Crypto import Random

#Other
import json
import time
import datetime

# %%
#Connect with DB
# Connect to MariaDB Platform
try:
    conn = mariadb.connect(
        user="airq",
        password="airq",
        host="localhost",
        port=3306,
        database="airq_data"

    )
except mariadb.Error as e:
    print(f"Error connecting to MariaDB Platform: {e}")
    sys.exit(1)

# Get Cursor
cur = conn.cursor()

# %%
# Verbindungsinformationen für den Air-q Sensor
airqIP = '192.168.4.1'
airqpass = 'airqsetup'
#########################

def unpad(data):
  return data[:-ord(data[-1])]

def decodeMessage(msgb64):
  # Erster Schritt: base64 dekodieren
  msg = base64.b64decode(msgb64)

  # AES-Schlüssel der Länge 32 aus dem air-Q-Passwort erstellen
  key = airqpass.encode('utf-8')
  if len(key) < 32:
    for i in range(32-len(key)):
      key += b'0'
  elif len(key) > 32:
    key = key[:32]

  # Zweiter Schritt: AES256 dekodieren
  cipher = AES.new(key=key, mode=AES.MODE_CBC, IV=msg[:16])
  return unpad(cipher.decrypt(msg[16:]).decode('utf-8'))

def pad(data):
  length = 16 - (len(data) % 16)
  return data + chr(length).encode('utf-8')*length

def encodeMessage(msg):
  # AES-Schlüssel der Länge 32 aus dem air-Q-Passwort erstellen
  key = airqpass.encode('utf-8')
  if len(key) < 32:
    for i in range(32-len(key)):
      key += b'0'
  elif len(key) > 32:
    key = key[:32]

  # Erster Schritt: AES256 verschlüsseln
  iv = Random.new().read(AES.block_size)
  cipher = AES.new(key=key, mode=AES.MODE_CBC, IV=iv)
  msg = msg.encode('utf-8')
  crypt = iv + cipher.encrypt(pad(msg))

  # Zweiter Schritt: base64 enkodieren
  msgb64 = base64.b64encode(crypt).decode('utf-8')
  return msgb64

#Gibt ein JSON-Objekt über die verfügbaren Daten zurück
def getAvailable():
    # Verbindung zum air-Q aufbauen
    connection = http.client.HTTPConnection(airqIP)

    # Daten anfordern
    connection.request("GET", "/dirbuff")
    contents = connection.getresponse()

    # Daten entschlüsseln
    msg = decodeMessage(contents.read())
  
    #JSON-String umwandeln in dict
    folder_dict = json.loads(msg)
    
    # Verbindung trennen
    connection.close()

    return folder_dict

# %%
#Funktion zur erstellung des SQL-Statements
def sql_data(contents, cur):
  #content wird Zeile für Zeile verarbeitet
  for line in contents.read().split(b'\n'):
      if line != b'':
          #Message wird dekodiert
          line = decodeMessage(line)
          #print(line)

          #Zeile wird in ein dict konvertiert
          line= json.loads(line)

          columns = ""
          values = ""

          if line["Status"] != "OK":
                  print(line["Status"])
                  print("Skipped invalid measurements due to warm-up of the Sensor")
                  continue
          
          for type in line:
              #Diese Daten werden herausgefiltert und nicht mit in die Datenbank mit aufgenommen
              if type == "bat" or type == "DeviceID" or type == "uptime" or type == "window_event" or type == "door_event" or type == "person" or type == "window_open" or type == "Status":
                continue

              
              #Erstellt den String für die Columns
              columns += type 

              #Erstellt den String für die Values 
              #Edge-case: wenn value eine Liste ist
              if isinstance(line[type], list):
                  values += str(line[type][0])
              elif type == "timestamp":
                  values += "FROM_UNIXTIME(%s)" % (int(line[type]/1000))
              else:  
                  values += str(line[type])

              #Edge-case: Am Ende kein Komma
              if type != "cnt0_3":  
                  columns += ", "
                  values += ", "

          sql = "INSERT IGNORE INTO %s ( %s ) VALUES ( %s );" % ('measurements', columns, values)
          #print(sql)
          cur.execute(sql)
          conn.commit()

# %%
def file_to_db(start_date, end_date):
    folder = getAvailable()

    # Verbindung zum air-Q aufbauen
    connection = http.client.HTTPConnection(airqIP)

    # Sortiere Ordner nach Jahr, Monat und Tag
    sorted_years = sorted(folder.keys())
    for year in sorted_years:
        sorted_months = sorted(folder[year].keys())
        for month in sorted_months:
            sorted_days = sorted(folder[year][month].keys())
            for day in sorted_days:
                sorted_files = sorted(folder[year][month][day])
                for file in sorted_files:
                    # Datumsobjekt erstellen
                    file_date = datetime.datetime.strptime(
                        year + month + day, "%Y%m%d"
                    ).date()

                     # Überprüfen, ob das Datum im gewünschten Zeitraum liegt
                    if start_date <= file_date <= end_date:

                        # Anfrage formulieren und Daten anfordern
                        print("_____________________________________________________________________________")
                        print("Year: " + year + "\n" + "Month: " + month + "\n" + "Day: " + day + "\n" + "File: " + file + "\n")
                        connection.request("GET", "/file?request=" + encodeMessage(year + "/" + month + "/" + day + "/" + file))
                        contents = connection.getresponse()
                        if contents.status == 200:
                            print("Status: " + str(contents.status) + "/OK")
                        else:
                            print("Status: " + str(contents.status) + "/Canceled!")
                            break
                        sql_data(contents, cur)

        # Verbindung trennen
        connection.close()

# %%
start_date = datetime.date(2023, 5, 1)
end_date = datetime.date(2023, 6, 23)
file_to_db(start_date, end_date)
# Out:
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682899212
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682902460
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682905708
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682908956
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682912206
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682915453
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682918700
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682921950
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682925196
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682928444
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682931690
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682935058
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682938307
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682941556
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682944804
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682948051
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682951300
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682954547
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682957794
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682961042
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682964290
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682967538
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682970785
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682974034
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682977282
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682980530
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 1
# File: 1682983779
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683676790
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683680038
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683683285
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683686535
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683689784
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683693032
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683696283
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683699531
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683702779
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683706027
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683709275
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683712522
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683715771
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683719020
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683722269
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683725518
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683728766
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683732018
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683735267
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683738518
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683741765
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683745011
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683748259
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683751507
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683754756
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683758004
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 10
# File: 1683761252
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683763177
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683766424
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683769672
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683772918
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683776167
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683779415
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683782663
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683785912
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683789162
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683792411
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683795658
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683798907
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683802155
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683805402
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683808650
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683811901
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683815149
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683818396
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683821644
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683824893
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683828142
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683831389
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683834637
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683837886
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683841136
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683844383
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 11
# File: 1683847629
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683849555
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683852802
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683856051
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683859299
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683862549
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683865798
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683869045
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683872293
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683875538
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683878788
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683882036
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683885286
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683888533
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683891782
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683895032
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683898280
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683901528
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683904777
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683908025
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683911271
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683914521
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683917770
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683921017
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683924262
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683927510
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683930759
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 12
# File: 1683934007
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683936052
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683939300
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683942549
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683945799
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683949049
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683952297
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683955544
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683958791
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683962041
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683965290
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683968541
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683971789
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683975039
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683978285
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683981533
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683984782
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683988031
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683991278
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683994526
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1683997773
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1684001021
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1684004270
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1684007517
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1684010765
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1684014012
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1684017260
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 13
# File: 1684020509
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684022433
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684025681
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684028930
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684032179
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684035428
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684038674
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684041924
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684045174
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684048420
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684051669
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684054916
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684058162
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684061410
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684064656
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684067906
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684071153
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684074402
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684077649
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684080898
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684084147
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684087395
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684090643
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684093890
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684097140
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684100388
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684103637
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 14
# File: 1684106885
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684108810
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684112059
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684115306
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684118555
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684121803
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684125052
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684128297
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684131545
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684134794
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684138042
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684141289
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684144537
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684147785
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684151033
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684154282
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684157532
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684160778
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684164027
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684167275
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684170524
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684173772
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684177021
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684180270
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684183515
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684186762
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684190012
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 15
# File: 1684193259
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684195184
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684198432
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684201680
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684204928
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684208177
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684211424
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684214672
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684217919
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684221167
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684224413
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684227659
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684230908
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684234157
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684237404
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684240651
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684243899
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684247146
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684250394
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684253640
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684256889
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684260135
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684263379
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684266626
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684269874
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684273122
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684276370
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 16
# File: 1684279618
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684281543
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684284792
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684288037
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684291287
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684294534
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684297783
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684301029
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684304277
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684307524
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684310772
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684314020
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684317267
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684320516
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684323763
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684327011
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684330258
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684333506
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684336752
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684339999
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684343248
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684346495
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684349742
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684352989
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684356236
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684359484
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684362733
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 17
# File: 1684365981
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684368025
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684371274
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684374523
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684377768
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684381014
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684384262
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684387510
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684390757
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684394005
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684397253
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684400501
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684403747
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684406995
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684410240
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684413489
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684416737
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684419983
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684423229
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684426477
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684429724
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684432974
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684436221
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684439469
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684442717
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684445965
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684449211
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 18
# File: 1684452457
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684454381
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684457628
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684460876
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684464123
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684467371
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684470618
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684473865
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684477112
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684480361
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684483608
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684486855
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684490103
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684493353
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684496601
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684499847
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684503093
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684506340
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684509589
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684512837
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684516084
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684519333
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684522582
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684525830
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684529077
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684532325
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684535571
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 19
# File: 1684538818
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1682985582
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1682988831
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1682992078
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1682995327
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1682998573
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683001819
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683005070
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683008317
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683011563
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683014810
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683018060
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683021307
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683024553
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683027802
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683031052
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683034300
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683037546
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683040795
#
# Status: 200/OK
# {'co': 'co sensor still in warm up phase; waiting time = 8 s', 'tvoc': 'tvoc sensor still in warm up phase; waiting time = 7 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 7 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 7 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 7 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683044188
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683047436
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683050683
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683053929
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683057175
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683060425
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683063673
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683066922
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 2
# File: 1683070171
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684540741
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684543990
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684547238
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684550486
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684553734
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684556981
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684560228
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684563476
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684566723
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684569970
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684573217
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684576466
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684579712
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684582961
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684586210
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684589456
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684592703
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684595951
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 5
# Day: 20
# File: 1684599197
#
# Status: 200/OK
# ...
# {'co': 'co sensor still in warm up phase; waiting time = 1281 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 3080 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 3081 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 3080 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'co': 'co sensor still in warm up phase; waiting time = 1160 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 2960 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 2960 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 2959 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'co': 'co sensor still in warm up phase; waiting time = 1040 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 2840 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 2840 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 2839 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'co': 'co sensor still in warm up phase; waiting time = 920 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 2720 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 2720 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 2719 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 7
# File: 1686159152
#
# Status: 200/OK
# {'co': 'co sensor still in warm up phase; waiting time = 800 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 2599 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 2600 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 2599 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'co': 'co sensor still in warm up phase; waiting time = 679 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 2479 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 2479 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 2478 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'co': 'co sensor still in warm up phase; waiting time = 559 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 2358 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 2359 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 2358 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'co': 'co sensor still in warm up phase; waiting time = 439 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 2238 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 2238 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 2238 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'co': 'co sensor still in warm up phase; waiting time = 319 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 2118 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 2119 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 2118 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'co': 'co sensor still in warm up phase; waiting time = 199 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 1998 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 1998 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 1998 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'co': 'co sensor still in warm up phase; waiting time = 78 s', 'so2': 'so2 sensor still in warm up phase; waiting time = 1877 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 1878 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 1877 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 1756 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 1756 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 1756 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 1636 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 1636 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 1636 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 1515 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 1515 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 1514 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 1396 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 1396 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 1395 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 1274 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 1274 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 1274 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 1155 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 1155 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 1155 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 1034 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 1034 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 1033 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 914 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 914 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 914 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 793 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 794 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 793 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 674 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 674 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 673 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 554 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 555 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 554 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 433 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 433 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 432 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 313 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 313 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 313 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 193 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 193 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 193 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# {'so2': 'so2 sensor still in warm up phase; waiting time = 72 s', 'no2': 'no2 sensor still in warm up phase; waiting time = 72 s', 'o3': 'o3 sensor still in warm up phase; waiting time = 71 s'}
# Skipped invalid measurements due to warm-up of the Sensor
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 7
# File: 1686161921
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 7
# File: 1686165168
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 7
# File: 1686168417
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 7
# File: 1686171664
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 7
# File: 1686174915
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 7
# File: 1686178163
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 7
# File: 1686181412
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686182375
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686185624
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686188872
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686192119
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686195368
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686198618
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686201865
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686205115
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686208364
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686211611
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686214859
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686217989
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686221115
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686224380
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686227662
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686230933
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686234208
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686237483
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686240755
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686244025
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686247294
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686250563
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686253708
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686256972
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686260230
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686263489
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 8
# File: 1686266619
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686268787
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686272067
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686275353
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686278634
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686281916
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686285201
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686288480
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686291759
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686295032
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686298314
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686301604
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686304890
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686308169
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686311451
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686314725
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686318006
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686321289
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686324565
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686327839
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686331103
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686334373
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686337639
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686340901
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686344160
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686347297
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686350436
#
# Status: 200/OK
# _____________________________________________________________________________
# Year: 2023
# Month: 6
# Day: 9
# File: 1686353576
#
# Status: 200/OK
